# %%
import pandas as pd
import json
from config import LIST_FILE

# %%
#bot_idents = pd.read_csv('data/cresci-rtbust-2019.tsv', sep='\t')

file_path = LIST_FILE[:-4] + ".json"

with open(file_path, 'r') as f:
    tweets = json.load(f) 
    print('Number of tweets found: ' + str(len(tweets)))

df = pd.json_normalize(tweets) 

df.head()
# Out:
#                                          u2664730894  \
# 0  [{'edit_history_tweet_ids': ['1598984718778699...
#
#                                          u1679822588  \
# 0  [{'edit_history_tweet_ids': ['1196413208053141...
#
#                                           u848975226  \
# 0  [{'edit_history_tweet_ids': ['1592270449232191...
#
#                                          u2465283662 u1275028426672549888  \
# 0  [{'edit_history_tweet_ids': ['1599533626303320...                   []
#
#                                 u1322906536029626368  \
# 0  [{'edit_history_tweet_ids': ['1401837135544598...
#
#                                           u935031277  \
# 0  [{'edit_history_tweet_ids': ['1598329974003580...
#
#                                           u213809534  \
# 0  [{'edit_history_tweet_ids': ['1499750900822429...
#
#                                            u10129132  \
# 0  [{'edit_history_tweet_ids': ['1460191310829158...
#
#                                            u29458079  ...  \
# 0  [{'edit_history_tweet_ids': ['1599425110620110...  ...
#
#                                            u76970495 u1391259944519880704  \
# 0  [{'edit_history_tweet_ids': ['1566011030567886...                   []
#
#                                 u1483772843016036353  \
# 0  [{'edit_history_tweet_ids': ['1504580089073307...
#
#                                            u14192174  \
# 0  [{'edit_history_tweet_ids': ['1595821030882545...
#
#                                 u1096777461189222401  \
# 0  [{'edit_history_tweet_ids': ['1597132993226678...
#
#                                 u1276516622694379520  \
# 0  [{'edit_history_tweet_ids': ['1520773108973830...
#
#                                            u20811737  \
# 0  [{'edit_history_tweet_ids': ['1599479983076184...
#
#                                 u1484032473063649280  \
# 0  [{'edit_history_tweet_ids': ['1491218874943283...
#
#                                 u1208765275878895617  \
# 0  [{'edit_history_tweet_ids': ['1599554253806247...
#
#                                           u262447355
# 0  [{'edit_history_tweet_ids': ['1597352998464016...
#
# [1 rows x 389 columns]
